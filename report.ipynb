# %%
# %pip install -e .
# Out:
# Obtaining file:///C:/Users/Wojtek/Git-Bash/Literary_Analysis
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\wojtek\git-bash\literary_analysis\.venv\lib\site-packages (from Literature_Analysis==1) (2.5.2)
# Collecting matplotlib (from Literature_Analysis==1)
#   Using cached matplotlib-3.11.1-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->Literature_Analysis==1)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->Literature_Analysis==1)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib->Literature_Analysis==1)
#   Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl.metadata (126 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->Literature_Analysis==1)
#   Using cached kiwisolver-1.5.1-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\wojtek\git-bash\literary_analysis\.venv\lib\site-packages (from matplotlib->Literature_Analysis==1) (26.3)
# Collecting pillow>=9 (from matplotlib->Literature_Analysis==1)
#   Using cached pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib->Literature_Analysis==1)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wojtek\git-bash\literary_analysis\.venv\lib\site-packages (from matplotlib->Literature_Analysis==1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\wojtek\git-bash\literary_analysis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->Literature_Analysis==1) (1.17.0)
# Using cached matplotlib-3.11.1-cp313-cp313-win_amd64.whl (9.3 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 23.0 MB/s eta 0:00:00
# Using cached kiwisolver-1.5.1-cp313-cp313-win_amd64.whl (70 kB)
# Using cached pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Building wheels for collected packages: Literature_Analysis
#   Building editable for Literature_Analysis (pyproject.toml): started
#   Building editable for Literature_Analysis (pyproject.toml): finished with status 'done'
#   Created wheel for Literature_Analysis: filename=literature_analysis-1-0.editable-py3-none-any.whl size=1440 sha256=497d58e328a076d3ca79e7643d7e7534ced1b2ecf02bb7419042d4ec4dead029
#   Stored in directory: C:\Users\Wojtek\AppData\Local\Temp\pip-ephem-wheel-cache-l5vo3b2m\wheels\e9\d7\76\22cc9977629ad092bc9c39f69dac4c6472f5784dde56913c3f
# Successfully built Literature_Analysis
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, Literature_Analysis
# Successfully installed Literature_Analysis-1 contourpy-1.3.3 cycler-0.12.1 fonttools-4.64.0 kiwisolver-1.5.1 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\Wojtek\Git-Bash\Literary_Analysis\.venv\Scripts\python.exe -m pip install --upgrade pip

# %% [markdown]
# Import modules

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# First of all, we have to load our data.

# %%
from literary_analysis.extracting_words import extract_words, extract_dictionary_words
from literary_analysis.read_works import file_counter, works_counter
from literary_analysis.save_results import calculate_statistics

# %%
paths = ["data/Ballady i Romanse.txt", "data/Pan Tadeusz (Gutenberg-sam tekst).txt", "data/laka lesmian.txt", "data/README.txt"]
all_works, total_counter, total_lines_count = works_counter(paths)

# %%
d_counter, d_n_of_lines = file_counter("data/odm.txt", word_extractor=extract_dictionary_words)

# %% [markdown]
# Let us present some basic statistics of our dicitionary:

# %%
print(calculate_statistics("dictionary", d_n_of_lines, d_counter))
# Out:
# dictionary statistics:
# Number of lines: 236006.
# Number of words: 4760935.
# Number of unique words: 4521735.
# Top 10 most frequent words:
# kurze: 11, ruski: 9, gotów: 8, kicie: 8, kole: 8, lipce: 8, rysie: 8, białka: 7, bury: 7, czarne: 7, dudkach: 7, dudkami: 7, dudki: 7, dudkom: 7, dziadzie: 7, gale: 7, inki: 7, kury: 7, mai: 7, maja: 7, majach: 7, majami: 7, maje: 7, majom: 7, mają: 7, marki: 7, mili: 7, misie: 7, zielonych: 7, zielonym: 7, zielonymi: 7
# How many times each letter appears:
# i 5476160, a 5167874, o 4785291, e 4761764, n 4185146, y 2787434, w 2741470, z 2716769, r 2580120, c 2418971, m 2222265, s 1944405, k 1860942, p 1650458, t 1646996, u 1507468, l 1397973, d 1231442, j 1096857, b 1024668, ł 1015635, g 779273, h 713745, ą 661555, ś 535394, ę 327584, ż 295783, f 270273, ó 203479, ń 154462, ć 51445, ź 36189, - 31795,   15499, v 10713, ' 5982, x 3966, q 2501, . 1506, é 626, ü 462, ö 269, á 91, ä 44, í 28, ë 22, à 21, è 17, ç 12, š 11, ú 9, ō 6, ê 5, 2 5, 3 5, â 3, å 3, ô 3, ø 2, û 2, 0 2, 1 2, 4 2, 6 2, 9 2, ; 2, î 1, ñ 1, ù 1, č 1, ş 1, ū 1, 5 1, 7 1, : 1

# %% [markdown]
# And now let us present the same stats but for our Master's works

# %%
print(calculate_statistics("all works", total_lines_count, total_counter, n_of_files=len(all_works)))
# Out:
# all works statistics:
# Number of all files: 4.
# Number of lines: 11725.
# Number of words: 59663.
# Number of unique words: 18434.
# Top 10 most frequent words:
# i: 2110, w: 1855, się: 1347, na: 1102, z: 810, nie: 694, do: 534, a: 508, jak: 501, to: 391
# How many times each letter appears:
# i 26763, a 26463, e 22066, o 20361, z 19345, n 14528, s 13812, w 13517, r 13056, c 12788, y 11056, d 10448, k 10442, t 9795, m 9761, ł 8670, p 7893, u 7063, j 6295, l 5765, b 5458, ę 4786, g 4557, ą 4055, h 3666, ż 2957, ś 2755, ó 2646, ć 1500, é 727, ń 629, ź 364, f 257, v 17, x 11, о 4, а 3, в 3, е 2, з 2, л 2, н 2, р 2, ю 2, à 1, д 1, у 1, ц 1, ш 1, я 1

# %% [markdown]
# Look now at each work seperately

# %%
for work, counter, lines_count in all_works:
        print(calculate_statistics(work, counter, lines_count))
# Out:
# data/Ballady i Romanse.txt statistics:
# Number of lines: 2913.
# Number of words: 10890.
# Number of unique words: 4687.
# Top 10 most frequent words:
# i: 376, w: 241, się: 194, na: 193, nie: 176, z: 164, to: 112, do: 99, a: 84, jak: 84
# How many times each letter appears:
# i 4961, a 4724, e 4191, z 3508, o 3411, n 2430, s 2276, c 2272, r 2189, w 2062, k 2056, d 1921, t 1832, y 1811, m 1776, ł 1422, p 1350, u 1346, j 1239, l 1005, b 991, ę 893, g 839, ą 679, h 627, ż 554, ś 500, ó 446, ć 242, ń 99, ź 77, f 37, о 4, а 3, в 3, v 2, е 2, з 2, л 2, н 2, р 2, ю 2, д 1, у 1, ц 1, ш 1, я 1
# data/Pan Tadeusz (Gutenberg-sam tekst).txt statistics:
# Number of lines: 4994.
# Number of words: 31080.
# Number of unique words: 11274.
# Top 10 most frequent words:
# i: 1008, w: 888, się: 705, na: 601, z: 402, jak: 302, do: 268, s: 256, że: 246, nie: 244
# How many times each letter appears:
# a 14603, i 14009, e 11071, o 10998, z 10496, s 8081, n 7715, w 7488, r 7232, c 6658, y 6217, k 5936, d 5602, t 5320, m 4912, ł 4773, p 4235, u 3736, l 3291, j 3156, b 2833, ę 2411, g 2366, ą 2143, h 1969, ż 1533, ó 1420, ś 1245, ć 844, é 727, ń 283, ź 212, f 175, v 6, x 6, à 1
# data/laka lesmian.txt statistics:
# Number of lines: 3810.
# Number of words: 17672.
# Number of unique words: 6588.
# Top 10 most frequent words:
# i: 726, w: 726, się: 448, na: 307, nie: 274, z: 244, a: 208, co: 190, do: 167, jak: 115, że: 115
# How many times each letter appears:
# i 7783, a 7124, e 6798, o 5943, z 5340, n 4371, w 3963, c 3852, r 3630, s 3446, m 3070, y 3026, d 2923, t 2634, ł 2472, k 2448, p 2299, u 1979, j 1896, b 1633, ę 1481, l 1462, g 1350, ą 1233, h 1067, ś 1010, ż 870, ó 779, ć 414, ń 247, ź 75, f 45, v 8, x 5
# data/README.txt statistics:
# Number of lines: 8.
# Number of words: 21.
# Number of unique words: 18.
# Top 10 most frequent words:
# pl: 2, sjp: 2, słownik: 2, apache: 1, attribution: 1, commons: 1, creative: 1, gpl: 1, https: 1, international: 1, lgpl: 1, licencjach: 1, na: 1, odmiany: 1, oraz: 1, słów: 1, udostępniany: 1, wersja: 1
# How many times each letter appears:
# a 12, n 12, i 10, o 9, p 9, s 9, t 9, l 7, c 6, e 6, r 5, j 4, w 4, h 3, m 3, ł 3, d 2, g 2, k 2, u 2, y 2, b 1, v 1, z 1, ó 1, ę 1

# %% [markdown]
# Now we will present all words that appeared in Master's work, but are not in our dictionary and how many times each words occur.

# %%
from literary_analysis.find_differences import words_not_in_dictionary
difference = words_not_in_dictionary(total_counter, d_counter)
print(", ".join(f"{word}: {count}" for word, count in difference))
# Out:
# jéj: 53, tém: 42, potém: 35, assessor: 25, nakształt: 22, téj: 21, daléj: 18, niéj: 18, zwolna: 17, zdaleka: 16, czem: 15, niemasz: 15, któréj: 13, nakoniec: 13, swéj: 12, tukaj: 12, wié: 12, drugiéj: 11, wtém: 11, dawniéj: 10, jednéj: 10, mniéj: 9, stoła: 9, wielkiéj: 9, zlekka: 9, będziem: 8, lepiéj: 8, niem: 8, niemógł: 8, niewiadomo: 8, całéj: 7, djabeł: 7, jakgdyby: 7, niém: 7, poglądał: 7, pokryjomu: 7, zdala: 7, każdéj: 6, myślił: 6, niebyło: 6, swem: 6, więcéj: 6, zgadulo: 6, śpiewulo: 6, asoka: 5, assessora: 5, bajdała: 5, dziecie: 5, dłużéj: 5, jednem: 5, książe: 5, niewidział: 5, roskazy: 5, takiéj: 5, świdryga: 5, czém: 4, dobrodziéj: 4, doweyko: 4, gorzéj: 4, innéj: 4, ktoby: 4, midryga: 4, mojéj: 4, murawego: 4, naoślep: 4, nawprost: 4, nawskroś: 4, nielada: 4, niemoże: 4, pięknéj: 4, pociemku: 4, przeciwnéj: 4, przynajmniéj: 4, skołuba: 4, szczególniéj: 4, twem: 4, waszéj: 4, wcwał: 4, wczora: 4, zawcześnie: 4, ztąd: 4, źwierzyny: 4, bajdale: 3, balada: 3, bardziéj: 3, biegą: 3, biórku: 3, bliżéj: 3, chróśniaku: 3, cichu: 3, ciemnéj: 3, ciszéj: 3, doweyki: 3, dusiołka: 3, dzisiejszéj: 3, długiemi: 3, grzybo: 3, głębokiém: 3, historja: 3, inaczéj: 3, jakiéj: 3, każdem: 3, kozodusin: 3, którem: 3, któremi: 3, któżby: 3, lewéj: 3, lilija: 3, męsczyzn: 3, młodu: 3, nacicha: 3, napewno: 3, niebiosów: 3, niebył: 3, niegdzie: 3, niejest: 3, niemogą: 3, niepodoba: 3, nię: 3, obrasku: 3, ow: 3, paciórek: 3, podniosłszy: 3, poglądając: 3, polszcze: 3, pururawa: 3, raczéj: 3, ramiony: 3, roskrzyżował: 3, rospaczy: 3, rosprawiał: 3, sagalasówki:
# Imagine that for each work you have a list of all the words in it and how often they appeared. Then take the top $n$ of those and compute how often they occur (let $w_i$ be the number of appearances of $i$th most popular word), i.e. for each word divide its cardinality by the number of all words in a work (let's call it $N$). That will create a sequence of numbers
# $$ u_1 = \frac{w_1}{N}, u_2 = \frac{w_2}{N},..., u_n = \frac{w_n}{N}, $$
# where $u_1 \geqslant u_2 \geqslant ... \geqslant u_n$ and $\sum_{i=1}^n u_i \leqslant 1$.
# Such sequence is a probability distribution cutted at first n values.
# To compare 2 works we need to have such sequence for both works, let's call them
# $u^{(1)} = (u^{(1)}_i)^n_{i=1}$ and $u^{(2)} = (u^{(2)}_i)^n_{i=1}$.
# Our measure will be a convex combination of two different measures of similarity of those two sequences. The first one is $L^1$ norm of their difference:
# $$ ||u^{(1)} - u^{(2)}||_{L^1} = \sum_{i=1}^n |u^{(1)}_i - u^{(2)}_i| $$
# Notice that $|u^{(1)}_i - u^{(2)}_i| \leqslant |u^{(1)}_i| + |u^{(2)}_i| = u^{(1)}_i + u^{(2)}_i$, so
# $$ ||u^{(1)} - u^{(2)}||_{L^1} = \sum_{i=1}^n |u^{(1)}_i - u^{(2)}_i| \leqslant \sum_{i=1}^n u^{(1)}_i + u^{(2)}_i \leqslant 1+1 = 2$$,
# therefore we will use
# $\frac{1}{2} ||u^{(1)} - u^{(2)}||_{L^1}$. Obviously
# $1 - \frac{1}{2} ||u^{(1)} - u^{(2)}||_{L^1} = 1$ if and only if $u^{(1)} = u^{(2)}$.
# The next metric is called **Jaccard index**. It measures how two sets are similar in shape. In its most basic form for two sets $A, B$ it's defined as
# $$ J(A,B) = \frac{|A \cap B|}{|A \cup B|}. $$
# Notice that $0 \leqslant J(A,B) \leqslant 1$ and $J(A,B) = 1$ if and only if $A=B$. We will use what its called **weighted Jaccard index** and its defined as
# $$ J_W(u^{(1)} , u^{(2)}) = \frac{\sum_{i=1}^n \min(u^{(1)}_i , u^{(2)}_i)}{\sum_{i=1}^n \max(u^{(1)}_i , u^{(2)}_i)}. $$
# We can imagine this as sum of Jaccard indexes between two rectangles: one has $1 \times u^{(1)}_i$ dimensions and the other are $1 \times u^{(2)}_i.$
# In total, our similarity mesaure is
# $$ m(u^{(1)} , u^{(2)}) = 100\left(  \alpha  J_W(u^{(1)} , u^{(2)}) + \left( 1 - \alpha \right) \left( 1 - \frac{1}{2} ||u^{(1)} - u^{(2)}||_{L^1} \right) \right). $$ Summing up all of our observations, we can see that
# $0 \leqslant m(u^{(1)} , u^{(2)}) \leqslant 100$ and if and $m(u^{(1)} , u^{(2)}) = 100$ only if $u^{(1)} = u^{(2)}$.
# We will use $\alpha = 0.5$ as deafult. Let us now compute how similar each work is to the other.

# %%
from literary_analysis.analyse import similarity_matrix, all_distributions
from literary_analysis.plotting_graphs import plot_similarities

# %%
all_works, _, _ = works_counter(paths)
all_names = [names for names, counter, lines in all_works]
all_distr = all_distributions(all_works, 24)
sim_mtx = similarity_matrix(all_distr, 0.5)
plot_similarities(sim_mtx, all_names, 1)
plot_similarities(sim_mtx, all_names, 0)
plot_similarities(sim_mtx, all_names, 3)
# Out:
# <Axes: title={'center': 'How similar is data/README.txt to other works'}, xlabel='Compared works', ylabel='Level of similarity'>

# %% [markdown]
# We can clearly see that works of the Master are pretty similar to each other, but when they are compared to very short text it differs a lot.
